# %% [markdown]
# <div style="color: hotpink; font-size: 40px; font-family: Times; font-weight: bold;">
# HDL & RTL</div>
#
# <div style="background-color: #f3e5ff; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# This notebook will help you understand HDL & RTL concepts.</div>

# %% [markdown]
# <div style="background-color: #fddbe5; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">HDL: hardware description language</h3>
# Common HDL Languages:
# <ul> <li>Verilog </li> </ul>
# <ul> <li>System Verilog </li> </ul>
# <ul> <li>VHDL </li> </ul>
# </div>

# %% [markdown]
# <div style="background-color: #fee4ec; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">RTL: register transfer level</h3>
# <ul> <li>registers that store data </li> </ul>
# <ul> <li>combinational logic that processes data</li> </ul>
# <ul> <li>how data moves between registers </li> </ul>
# <ul> <li>what happens on each clock edge </li> </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #feedf2; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">HDL vs RTL:</h3>
# <ul> <li>HDL is language to describe hardware </li> </ul>
# <ul> <li>RTL is level of hardware design written with HDL</li> </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #fcd2df; padding: 12px; border-radius: 10px; font-size: 20px; font-weight: bold; font-family: Times;">
# HDL to RTL Design Process (ex: Verilog):
# </div>

# %% [markdown]
# <div style="background-color: #ffe3f9; padding: 12px; border-radius: 10px; font-size: 20px; font-weight: bold; font-family: Times;">
# Step 1: Write the HDL Code
# </div>

# %%
# assign y = a & b;

# %% [markdown]
# * <div style="background-color: #feedf2; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# this demonstrates an AND gate
# </div>

# %% [markdown]
# <div style="background-color: #ffe3f9; padding: 12px; border-radius: 10px; font-size: 20px; font-weight: bold; font-family: Times;">
# Step 2: Simulate the Design
# </div>

# %%
# a = 0;
# b = 0;

# a = 0;
# b = 1;

# a = 1;
# b = 0;

# a = 1;
# b = 1;

# %% [markdown]
# * <div style="background-color: #feedf2; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# this demonstrates a testbench, which provides different inputs and checks the outputs

# %% [markdown]
# <div style="background-color: #ffe3f9; padding: 12px; border-radius: 10px; font-size: 20px; font-weight: bold; font-family: Times;">
# Step 3: Synthesize the design
# </div>

# %%
# assign sum = a + b;

# %% [markdown]
# * <div style="background-color: #feedf2; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# this demonstrates a synthesis tool creating an adder circuit

# %% [markdown]
# <div style="background-color: #ffe3f9; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Step 4: View the RTL Schematic</h3>
#
# <div style="background-color: #feedf2; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <ul> <li>this allows the designer to check whether the HDL created the intended hardware</li> </ul>
# </div>

# %% [markdown]
# <div style="background-color: #ffe3f9; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Step 5: Implementation
# </h3>
#
# <div style="background-color: #feedf2; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <ul> <li>Translation: combines the design files</li> </ul>
# <ul> <li>Mapping: maps the logic to FPGA resources</li> </ul>
# <ul> <li>Placement: chooses physical FPGA locations</li> </ul>
# <ul> <li>Routing: connects the FPGA components</li> </ul>
# <ul> <li>Bitstream Generation: creates the file used to program the FPGA</li> </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #c1eeed; padding: 12px; border-radius: 10px; font-size: 20px; font-weight: bold; font-family: Times;">
# Concepts:
# </div>

# %% [markdown]
# <div style="background-color: #e0f7f6; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px;"><b>Combinational Logic:</b></h3>
# <ul> <li>depends only on the current inputs</li> </ul>
#
# <div style="background-color: #effbfa; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# Examples:
# <br><ul> <li>logic gates</li> </ul>
# <ul> <li>adders</li> </ul>
# <ul> <li>comparators</li> </ul>
# <ul> <li>multiplexers</li> </ul>
# <ul> <li>decoders</li> </ul>
# <br>
# </div>

# %%
# assign y = (a & b) | c;

# %% [markdown]
# * <div style="background-color: #effbfa; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# output changes whenever a, b, or c changes
# </div>
# * <div style="background-color: #effbfa; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# no clock and no stored value</div>

# %% [markdown]
# <div style="background-color: #e0f7f6; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Sequential Logic:</h3>
# <ul> <li>depends on current inputs, previously stored values, a clock signal</li> </ul>
#
# <div style="background-color: #effbfa; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# Examples:
# <br><ul> <li>registers</li> </ul>
# <ul> <li>counters</li> </ul>
# <ul> <li>shift registers</li> </ul>
# <ul> <li>state machines</li> </ul>
#
# </div>

# %%
# always @(posedge clk) begin
    # count <= count + 1; 
# end

# %% [markdown]
# * <div style="background-color: #effbfa; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# counter increases on every rising clock edge</div>

# %% [markdown]
# <div style="background-color: #e0f7f6; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Blocking and Nonblocking Assignments:</h3>
#
# <ul> <li><b>blocking ('='):</b>
# usually used for combinational logic</li> </ul>
#
# </div>

# %%
# always @(*) begin
    # y = a & b;
# end

# %% [markdown]
# * <div style="background-color: #effbfa; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# statements execute in order inside the block
# </div>

# %% [markdown]
# <div style="background-color: #e0f7f6; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
#
# <ul> <li><b>nonblocking ('='):</b>
# usually used for sequential logic</li> </ul>
# </div>

# %%
# always @(posedge clk) begin
    # q <= d; 
# end

# %% [markdown]
# * <div style="background-color: #e0f7f6; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# all register updates occur together at the clock edge
# </div>

# %% [markdown]
# <div style="background-color: #e0f7f6; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Registers:</h3>
#
# <ul> <li>
# stores a binary value</li> </ul>
#
# </div>

# %%
# always @(posedge clk) begin
    # data_out <= data_in;
# end

# %% [markdown]
# * <div style="background-color: #effbfa; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# output keeps its value until another clock edge occurs
# </div>

# %% [markdown]
# <div style="background-color: #e0f7f6; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Reset Signals:</h3>
#
# <ul> <li>
# reset places a circuit into a known starting state</li> </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #e0f7f6; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
#
# <ul> <li><b>synchronous reset:</b>
# reset is checked only on the clock edge </li> </ul>
# </div>

# %%
# always @(posedge clk) begin
    # if (reset)
        # count <= 0;
    # else
        # count <= count + 1;
# end

# %% [markdown]
# <div style="background-color: #e0f7f6; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
#
# <ul> <li><b>asynchronous reset:</b>
# reset can affect the circuit immediately </li> </ul>
# </div>

# %%
# always @(posedge clk or posedge reset) begin
    # if (reset)
        # count <= 0;
    # else
        # count <= count + 1;
# end

# %% [markdown]
# <div style="background-color: #e0f7f6; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Finite State Machine (FSM):</h3>
#
# <ul> <li>
# controls how a digital system moves between different operating states</li> </ul>
#
# <div style="background-color: #effbfa; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# Examples:
# <br><ul> <li>IDLE</li> </ul>
# <ul> <li>START</li> </ul>
# <ul> <li>READ</li> </ul>
# <ul> <li>WRITE</li> </ul>
# <ul> <li>DONE</li> </ul>
#
# <h3 style="font-size: 20px; font-weight: bold;">FSM usually contains:</h3>
#
# <div style="background-color: #e0f7f6; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <ul> <li>a state register</li> </ul>
# <ul> <li>next-state logic</li> </ul>
# <ul> <li>output logic</li> </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #e5d1fe; padding: 12px; border-radius: 10px; font-size: 20px; font-weight: bold; font-family: Times;">
# HDL vs C Programming/Python:
# </div>

# %% [markdown]
# <div style="background-color: #ecdcfe; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Sequential & Concurrent Operation:</h3>
#
# <ul> <li>C and Python normally execute instructions one after another </li> </ul>
# <ul> <li>HDL statements can represent separate hardware circuits that operate at the same time </li> </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #f2e8ff; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Code Creation:</h3>
#
# <ul> <li>in C or Python, the code becomes instructions for an existing processor:</li> </ul>
# <ul><ul>C/Python code → software instructions → processor executes instructions</ul></ul>
#
# <ul> <li>in HDL, the code describes and becomes a hardware circuit:</li> </ul>
# <ul><ul>HDL code → synthesis → gates, registers and connections</ul></ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #f9f3ff; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Timing & Clocks:</h3>
#
# <ul> <li>C and Python do not normally describe clock edges directly, the processor automatically controls when software instructions are executed </li> </ul>
# <ul> <li>HDL frequently uses a clock to control when data is stored or updated</li> </ul>
#
# </div>
