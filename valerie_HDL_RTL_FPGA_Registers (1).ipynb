# %% [markdown]
# <div style="color: hotpink; font-size: 40px; font-family: Times; font-weight: bold;">
# HDL, RTL, FPGA, & Registers</div>
#
# <div style="background-color: #f3e5ff; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# This notebook will help you understand HDL, RTL, FPGA, and Register concepts.</div>

# %% [markdown]
# <div style="background-color: #fddbe5; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">HDL: hardware description language</h3>
# Common HDL Languages:
# <ul> <li>Verilog </li> </ul>
# <ul> <li>System Verilog </li> </ul>
# <ul> <li>VHDL </li> </ul>
# </div>

# %% [markdown]
# <div style="background-color: #fee4ec; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">RTL: register transfer level</h3>
# <ul> <li>registers that store data </li> </ul>
# <ul> <li>combinational logic that processes data</li> </ul>
# <ul> <li>how data moves between registers </li> </ul>
# <ul> <li>what happens on each clock edge </li> </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #feedf2; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">HDL vs RTL:</h3>
# <ul> <li>HDL is language to describe hardware </li> </ul>
# <ul> <li>RTL is level of hardware design written with HDL</li> </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #fcd2df; padding: 12px; border-radius: 10px; font-size: 20px; font-weight: bold; font-family: Times;">
# HDL to RTL Design Process (ex: Verilog):
# </div>

# %% [markdown]
# <div style="background-color: #ffe3f9; padding: 12px; border-radius: 10px; font-size: 20px; font-weight: bold; font-family: Times;">
# Step 1: Write the HDL Code
# </div>

# %%
# assign y = a & b;

# %% [markdown]
# * <div style="background-color: #feedf2; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# this demonstrates an AND gate
# </div>

# %% [markdown]
# <div style="background-color: #ffe3f9; padding: 12px; border-radius: 10px; font-size: 20px; font-weight: bold; font-family: Times;">
# Step 2: Simulate the Design
# </div>

# %%
# a = 0;
# b = 0;

# a = 0;
# b = 1;

# a = 1;
# b = 0;

# a = 1;
# b = 1;

# %% [markdown]
# * <div style="background-color: #feedf2; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# this demonstrates a testbench, which provides different inputs and checks the outputs

# %% [markdown]
# <div style="background-color: #ffe3f9; padding: 12px; border-radius: 10px; font-size: 20px; font-weight: bold; font-family: Times;">
# Step 3: Synthesize the design
# </div>

# %%
# assign sum = a + b;

# %% [markdown]
# * <div style="background-color: #feedf2; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# this demonstrates a synthesis tool creating an adder circuit

# %% [markdown]
# <div style="background-color: #ffe3f9; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Step 4: View the RTL Schematic</h3>
#
# <div style="background-color: #feedf2; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <ul> <li>this allows the designer to check whether the HDL created the intended hardware</li> </ul>
# </div>

# %% [markdown]
# <div style="background-color: #ffe3f9; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Step 5: Implementation
# </h3>
#
# <div style="background-color: #feedf2; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <ul> <li>Translation: combines the design files</li> </ul>
# <ul> <li>Mapping: maps the logic to FPGA resources</li> </ul>
# <ul> <li>Placement: chooses physical FPGA locations</li> </ul>
# <ul> <li>Routing: connects the FPGA components</li> </ul>
# <ul> <li>Bitstream Generation: creates the file used to program the FPGA</li> </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #c1eeed; padding: 12px; border-radius: 10px; font-size: 20px; font-weight: bold; font-family: Times;">
# Concepts:
# </div>

# %% [markdown]
# <div style="background-color: #e0f7f6; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px;"><b>Combinational Logic:</b></h3>
# <ul> <li>depends only on the current inputs</li> </ul>
#
# <div style="background-color: #effbfa; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# Examples:
# <br><ul> <li>logic gates</li> </ul>
# <ul> <li>adders</li> </ul>
# <ul> <li>comparators</li> </ul>
# <ul> <li>multiplexers</li> </ul>
# <ul> <li>decoders</li> </ul>
# <br>
# </div>

# %%
# assign y = (a & b) | c;

# %% [markdown]
# * <div style="background-color: #effbfa; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# output changes whenever a, b, or c changes
# </div>
# * <div style="background-color: #effbfa; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# no clock and no stored value</div>

# %% [markdown]
# <div style="background-color: #e0f7f6; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Sequential Logic:</h3>
# <ul> <li>depends on current inputs, previously stored values, a clock signal</li> </ul>
#
# <div style="background-color: #effbfa; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# Examples:
# <br><ul> <li>registers</li> </ul>
# <ul> <li>counters</li> </ul>
# <ul> <li>shift registers</li> </ul>
# <ul> <li>state machines</li> </ul>
#
# </div>

# %%
# always @(posedge clk) begin
    # count <= count + 1; 
# end

# %% [markdown]
# * <div style="background-color: #effbfa; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# counter increases on every rising clock edge</div>

# %% [markdown]
# <div style="background-color: #e0f7f6; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Blocking and Nonblocking Assignments:</h3>
#
# <ul> <li><b>blocking ('='):</b>
# usually used for combinational logic</li> </ul>
#
# </div>

# %%
# always @(*) begin
    # y = a & b;
# end

# %% [markdown]
# * <div style="background-color: #effbfa; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# statements execute in order inside the block
# </div>

# %% [markdown]
# <div style="background-color: #e0f7f6; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
#
# <ul> <li><b>nonblocking ('='):</b>
# usually used for sequential logic</li> </ul>
# </div>

# %%
# always @(posedge clk) begin
    # q <= d; 
# end

# %% [markdown]
# * <div style="background-color: #e0f7f6; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# all register updates occur together at the clock edge
# </div>

# %% [markdown]
# <div style="background-color: #e0f7f6; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Registers:</h3>
#
# <ul> <li>
# stores a binary value</li> </ul>
#
# </div>

# %%
# always @(posedge clk) begin
    # data_out <= data_in;
# end

# %% [markdown]
# * <div style="background-color: #effbfa; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# output keeps its value until another clock edge occurs
# </div>

# %% [markdown]
# <div style="background-color: #e0f7f6; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Reset Signals:</h3>
#
# <ul> <li>
# reset places a circuit into a known starting state</li> </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #e0f7f6; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
#
# <ul> <li><b>synchronous reset:</b>
# reset is checked only on the clock edge </li> </ul>
# </div>

# %%
# always @(posedge clk) begin
    # if (reset)
        # count <= 0;
    # else
        # count <= count + 1;
# end

# %% [markdown]
# <div style="background-color: #e0f7f6; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
#
# <ul> <li><b>asynchronous reset:</b>
# reset can affect the circuit immediately </li> </ul>
# </div>

# %%
# always @(posedge clk or posedge reset) begin
    # if (reset)
        # count <= 0;
    # else
        # count <= count + 1;
# end

# %% [markdown]
# <div style="background-color: #e0f7f6; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Finite State Machine (FSM):</h3>
#
# <ul> <li>
# controls how a digital system moves between different operating states</li> </ul>
#
# <div style="background-color: #effbfa; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# Examples:
# <br><ul> <li>IDLE</li> </ul>
# <ul> <li>START</li> </ul>
# <ul> <li>READ</li> </ul>
# <ul> <li>WRITE</li> </ul>
# <ul> <li>DONE</li> </ul>
#
# <h3 style="font-size: 20px; font-weight: bold;">FSM usually contains:</h3>
#
# <div style="background-color: #e0f7f6; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <ul> <li>a state register</li> </ul>
# <ul> <li>next-state logic</li> </ul>
# <ul> <li>output logic</li> </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #e5d1fe; padding: 12px; border-radius: 10px; font-size: 20px; font-weight: bold; font-family: Times;">
# HDL vs C Programming/Python:</div>

# %% [markdown]
# <div style="background-color: #ecdcfe; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Sequential & Concurrent Operation:</h3>
#
# <ul> <li>C and Python normally execute instructions one after another </li> </ul>
# <ul> <li>HDL statements can represent separate hardware circuits that operate at the same time </li> </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #f2e8ff; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Code Creation:</h3>
#
# <ul> <li>in C or Python, the code becomes instructions for an existing processor:</li> </ul>
# <ul><ul>C/Python code → software instructions → processor executes instructions</ul></ul>
#
# <ul> <li>in HDL, the code describes and becomes a hardware circuit:</li> </ul>
# <ul><ul>HDL code → synthesis → gates, registers and connections</ul></ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #f9f3ff; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Timing & Clocks:</h3>
#
# <ul> <li>C and Python do not normally describe clock edges directly, the processor automatically controls when software instructions are executed </li> </ul>
# <ul> <li>HDL frequently uses a clock to control when data is stored or updated</li> </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #e2d6c4; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Field Programmable Gate Array (FPGA) Structure:</h3>
#
# <ul> <li>an integrated circuit that can be configured by the user to create custom digital hardware</li> </ul>
# <ul> <li>contains programmable hardware resources that can be connected together to build a circuit </li> </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #e9e0d2; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Configurable Logic Blocks (CLB):</h3>
# <ul> <li>the main areas of an FPGA where digital logic and data storage are created</li> </ul>
#
# <div style="background-color: #f1eae1; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
#     <b>CLBs can be used to create:</b>
# <br><ul> <li>logic gates</li> </ul>
# <ul> <li>adders</li> </ul>
# <ul> <li>comparators</li> </ul>
# <ul> <li>counters</li> </ul>
# <ul> <li>registers</li> </ul>
# <ul> <li>multiplexers</li> </ul>
# <ul> <li>state machines</li> </ul>
#
# <br>
# <b>an FPGA contains many CLBs arranged in a grid:</b>
#
# CLB   CLB   CLB   CLB
#
# CLB   CLB   CLB   CLB
#
# CLB   CLB   CLB   CLB
#
# <ul> <li>programmable routing connects the CLBs together</li> </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #e9e0d2; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Look-Up Tables (LUT):</h3>
# <ul> <li>performs combinational logic by storing the outputs of a Boolean truth table</li> </ul>
#
# <div style="background-color: #f1eae1; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <b>LUT can implement logic functions such as:</b>
# <br><ul> <li>AND</li> </ul>
# <ul> <li>OR</li> </ul>
# <ul> <li>XOR</li> </ul>
# <ul> <li>NAND</li> </ul>
# <ul> <li>comparators</li> </ul>
# <ul> <li>multiplexers</li> </ul>
# </div>

# %% [markdown]
# <div style="background-color: #e9e0d2; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Flip-Flops & Registers:</h3>
#
# <ul> <li>store binary data and update their values when a clock edge occurs</li> </ul>
#
# <div style="background-color: #f1eae1; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <ul> <li>flip-flop stores one bit of data, multiple flip-flops can be combined to create a register that stores several bits</li> </ul>
# <b>Flip-Flops can be used to create:</b>
# <ul> <li>registers</li> </ul>
# <ul> <li>counters</li> </ul>
# <ul> <li>shift registers</li> </ul>
# <ul> <li>state machines</li> </ul>
# <ul> <li>data pipelines</li> </ul>
#
# <br>
# <b>LUTs perform calculations, while flip-flops store the results:</b>
#
# <ul> <li>input → LUT logic → flip-flop → output</li> </ul>
#
#
# </div>

# %% [markdown]
# <div style="background-color: #e9e0d2; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Programmable Routing:</h3>
#
# <ul> <li>provides the wires and connections that allow FPGA components to communicate with one another</li> </ul>
#
# <div style="background-color: #f1eae1; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <b>Routing can connect:</b>
# <ul> <li>LUTs to flip-flops</li> </ul>
# <ul> <li>one configurable logic block to another</li> </ul>
# <ul> <li>logic blocks to memory</li> </ul>
# <ul> <li>logic blocks to DSP blocks</li> </ul>
# <ul> <li>logic blocks to input/output pins</li> </ul>
#
# <br>
# <b>LUTs perform calculations, while flip-flops store the results:</b>
#
# <ul> <li>placement & routing: during FPGA implementation, the design software decides where each component should be placed and how the components should be connected</li> </ul>
# <ul> <li>without programmable routing, the FPGA components would not be able to work together as one complete circuit</li> </ul>
#
#
# </div>

# %% [markdown]
# <div style="background-color: #e9e0d2; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Input/Output Blocks (IOB):</h3>
#
# <ul> <li>connect the internal FPGA circuit to external devices and physical pins</li> </ul>
#
# <div style="background-color: #f1eae1; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <b>FPGA pins may be configured as:</b>
# <ul> <li>inputs</li> </ul>
# <ul> <li>outputs</li> </ul>
# <ul> <li>bidirectional signals</li> </ul>
# <b>they can connect the FPGA to:</b>
# <ul> <li>pushbuttons</li> </ul>
# <ul> <li>switches</li> </ul>
# <ul> <li>LEDs</li> </ul>
# <ul> <li>sensors</li> </ul>
# <ul> <li>displays</li> </ul>
# <ul> <li>motors</li> </ul>
# <ul> <li>communication devices</li> </ul>
#
#
# </div>

# %% [markdown]
# <div style="background-color: #e9e0d2; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Block RAM (BRAM):</h3>
#
# <ul> <li>dedicated memory inside the FPGA that efficiently stores larger amounts of data</li> </ul>
#
# <div style="background-color: #f1eae1; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <b>BRAM can store:</b>
# <ul> <li>program data</li> </ul>
# <ul> <li>instructions</li> </ul>
# <ul> <li>images</li> </ul>
# <ul> <li>audio samples</li> </ul>
# <ul> <li>sensor readings</li> </ul>
# <ul> <li>communication buffers</li> </ul>
# <ul> <li>look-up tables</li> </ul>
# <b>BRAM can be configured with different:</b>
# <ul> <li>memory sizes</li> </ul>
# <ul> <li>data widths</li> </ul>
# <ul> <li>memory depths</li> </ul>
# <ul> <li>read & write ports</li> </ul>
#
#
# </div>

# %% [markdown]
# <div style="background-color: #e9e0d2; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Digital Signal Processing (DSP):</h3>
#
# <ul> <li>specialized hardware components that perform mathematical operations quickly and efficiently</li> </ul>
#
# <div style="background-color: #f1eae1; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <b>DSP blocks can perform operations such as:</b>
# <ul> <li>multiplication</li> </ul>
# <ul> <li>additions</li> </ul>
# <ul> <li>subtraction</li> </ul>
# <ul> <li>multiply accumulate operations</li> </ul>
# <ul> <li>signal filtering</li> </ul>
# <b>they are commonly used in:</b>
# <ul> <li>audio processing</li> </ul>
# <ul> <li>image processing</li> </ul>
# <ul> <li>robotics</li> </ul>
# <ul> <li>motor control</li> </ul>
# <ul> <li>machine learning</li> </ul>
# <ul> <li>communication systems</li> </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #e9e0d2; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Clock Resources:</h3>
#
# <ul> <li>distributes timing signals throughout the FPGA so that sequential components update at the correct time</li> </ul>
#
# <div style="background-color: #f1eae1; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <ul> <li>a clock coordinates when registers and flip-flops store new data</li> </ul>
#
# <b>FPGA clock resources may include:</b>
# <ul> <li>clock input pins</li> </ul>
# <ul> <li>clock buffers</li> </ul>
# <ul> <li>dedicated clock-routing networks</li> </ul>
# <ul> <li>phase-locked loops</li> </ul>
# <ul> <li>mixed-mode clock managers</li> </ul>
#
# <br><ul> <li>dedicated clock networks help deliver the clock across the FPGA with minimal timing differences</li> </ul>
#
#
# </div>

# %% [markdown]
# <div style="background-color: #e9e0d2; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Hard Processing Blocks:</h3>
#
# <ul> <li>permanent, specialized components already built into some FPGA devices</li> </ul>
# <ul> <li>unlike LUTs and flip-flops, hard blocks are not created from programmable logic</li> </ul>
#
# <div style="background-color: #f1eae1; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <b>Hard Processing Block examples:</b>
# <ul> <li>ARM processors</li> </ul>
# <ul> <li>memory controllers</li> </ul>
# <ul> <li>ethernet controllers</li> </ul>
# <ul> <li>PCI express controllers</li> </ul>
# <ul> <li>high-speed communication transceivers</li> </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #e9e0d2; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Configuration Memory & Bitstream:</h3>
#
# <ul> <li>stores the information that tells the FPGA how its logic and connections should be programmed</li> </ul>
#
# <div style="background-color: #f1eae1; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <b>FPGA configuration determines:</b>
# <ul> <li>what each LUT does</li> </ul>
# <ul> <li>how the routing is connected</li> </ul>
# <ul> <li>how registers behave</li> </ul>
# <ul> <li>how input/output pins operate</li> </ul>
# <ul> <li>how memory and DSP blocks are configured</li> </ul>
#
#
# <br>
# <ul><li><b>bitstream:</b> the file used to program the FPGA</li></ul>
# <ul>HDL design → synthesis → implementation → bitstream</ul>
# <ul><li>when the bitstream is loaded, the FPGA becomes the digital circuit described by the HDL code</li></ul>
# <ul><li>many FPGAs lose their configuration when power is removed, so the bitstream must be loaded again when the board starts</li></ul>
#
#
# </div>

# %% [markdown]
# <div style="background-color: #e9e0d2; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">How HDL Uses FPGA Resources:</h3>
#
# <ul> <li>when HDL code is synthesized, the FPGA design software converts the code into available hardware resources</li> </ul>
#
# <div style="background-color: #f1eae1; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <ul> <li>boolean expression → LUT</li> </ul>
# <ul> <li>clocked assignment → flip-flop</li> </ul>
# <ul> <li>counter → LUT & flip-flops</li> </ul>
# <ul> <li>large memory → block RAM</li> </ul>
# <ul> <li>multiplication → DSP block</li> </ul>
# <ul> <li>external signal → input/output block</li> </ul>
# <ul> <li>signal connections → programmable routing</li> </ul>
#
#
# <br>
# <ul><li><b>bitstream:</b> the file used to program the FPGA</li></ul>
# <ul>HDL design → synthesis → implementation → bitstream</ul>
# <ul><li>when the bitstream is loaded, the FPGA becomes the digital circuit described by the HDL code</li></ul>
# <ul><li>many FPGAs lose their configuration when power is removed, so the bitstream must be loaded again when the board starts</li></ul>
#
#
# </div>

# %% [markdown]
# <div style="background-color: #9bd0ff; padding: 12px; border-radius: 10px; font-size: 20px; font-weight: bold; font-family: Times;">
# FPGA vs PLD:</div>

# %% [markdown]
# <div style="background-color: #7ed4e6; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Programmable Logic Device (PLD):</h3>
#
# <ul> <li>digital device that can be programmed to perform a specific logic function</li> </ul>
# <ul> <li>allows a designer to create custom hardware without manufacturing a completely new integrated circuit</li> </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #b9deff; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Relationship Between FPGAs & PLDs:</h3>
#
# <ul> <li>PLD refers to the entire family of programmable logic devices, while FPGA refers to one specific and more advanced type</li> </ul>
#
# <div style="background-color: #d1e9ff; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <ul> <li>an FPGA is a type of PLD</li> </ul>
# <ul> <li>every FPGA is a PLD, but not every PLD is an FPGA</li> </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #b9deff; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Simple PLDs:</h3>
#
# <ul> <li>small programmable devices used for basic Boolean logic and control functions</li> </ul>
#
# <div style="background-color: #d1e9ff; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <b>simple PLD examples:</b>
# <ul> <li>PAL</li> </ul>
# <ul> <li>PLA</li> </ul>
# <ul> <li>GAL</li> </ul>
#
#
# <br><b>they are commonly used to create:</b>
# <ul> <li>logic gates</li> </ul>
# <ul> <li>small decoders</li> </ul>
# <ul> <li>address-selection circuits</li> </ul>
# <ul> <li>simple control logic</li> </ul>
# <ul> <li>small state machines</li> </ul>
#
# <br><ul> <li>simple PLDs contain fewer logic resources than FPGAs </li> </ul>
# <ul> <li>they are suitable when the design only requires a small number of inputs, outputs, and logic equations</li> </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #b9deff; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Complex PLDs (CPLD):</h3>
#
# <ul> <li>a medium-sized programmable device built from several logic blocks connected through programmable routing</li> </ul>
#
# <div style="background-color: #d1e9ff; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <b>they are commonly used for:</b>
# <ul> <li>startup control</li> </ul>
# <ul> <li>reset circuits</li> </ul>
# <ul> <li>address decoding</li> </ul>
# <ul> <li>interface control</li> </ul>
# <ul> <li>small state machines</li> </ul>
# <ul> <li>combining several simple logic functions</li> </ul>
#
# <br><ul> <li>CPLDs commonly use larger logic structures called macrocells</li> </ul>
# <ul> <li><b>macrocells</b>: a programmable logic block in a PLD or CPLD that performs a logic function and can optionally store the result</li> </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #b9deff; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Logic Capacity:</h3>
#
# <ul> <li>how much digital hardware can be created inside the device</li> </ul>
#
# <div style="background-color: #d1e9ff; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <ul> <li>a basic PLD may only contain enough resources for a small circuit</li> </ul>
# <ul> <li>an FPGA may contain thousands or millions of programmable logic elements</li> </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #b9deff; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Routing:</h3>
#
# <ul> <li>determines how the programmable logic components are connected</li> </ul>
#
# <div style="background-color: #d1e9ff; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <ul> <li>PLDs and CPLDs usually have simpler routing structures, making their timing more predictable</li> </ul>
# <ul> <li>FPGAs contain much larger routing networks because they must connect many logic blocks, memories, DSP units, and input/output pins, providing more flexibility, but also making placement and timing more complex</li> </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #d4e7c9; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Registers:</h3>
#
# <ul> <li>a group of flip-flops used to store multiple bits of binary data inside a digital circuit</li> </ul>
# <ul> <li>a register temporarily stores data inside a processor, FPGA, or other digital system</li> </ul>
# <ul> <li>each flip-flop stores one bit, so multiple flip-flops are combined to store a larger binary value</li> </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #e2efdb; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">How Does a Register Work:</h3>
#
# <ul> <li>a register stores its input value when an active clock edge occurs and keeps that value until the next update</li> </ul>
#
# <div style="background-color: #f1f7ed; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <ul><li><b>a register usually has:</b></li> </ul>
# <ul> <li>data input</li> </ul>
# <ul> <li>data output</li> </ul>
# <ul> <li>clock input</li> </ul>
# <ul> <li>optional reset</li> </ul>
# <ul> <li>optional enable signal</li> </ul>
#
#
# <br>
# <ul><li><b>a simple register can be represented as:</b></li></ul>
# data input → register → data output
# <ul><ul><ul>    ↑ clock</ul></ul></ul>
#
# <ul><li>when the rising clock edge occurs, the register copies the input value and stores it at the output</li></ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #e2efdb; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Clock Signal:</h3>
#
# <ul> <li>determines when a register is allowed to store a new value </li> </ul>
#
# </div>

# %%
# always @(posedge clk)

# %% [markdown]
# <div style="background-color: #f1f7ed; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <ul> <li>registers are sequential components, meaning they normally update only when a specific clock event occurs</li> </ul>
# <ul><li><b>'posedge':</b> positive/rising edge</li> </ul>
# <ul> <li>a risng edge occurs when the clock changes from 0 → 1 </li></ul>
# <ul> <li>register keeps its stored value between clock edges</li> </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #e2efdb; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Register with Reset:</h3>
#
# <ul> <li>a reset places the register into a known starting value</li> </ul>
#
# </div>

# %%
# always @(posedge clk) begin 
    # if (reset) 
        # data_register <= 8'b00000000; 
    # else 
        # data_register <= data_in; 
# end

# %% [markdown]
# <div style="background-color: #f1f7ed; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <ul> <li>when reset is active, the register is cleared to zero</li> </ul>
# <ul><li>when reset is inactive, the register stores data_in</li> </ul>
# <ul><li>reset is useful because it ensures that the circuit begins in a predictable state</li> </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #e2efdb; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Register with Enable:</h3>
#
# <ul> <li>an enable signal controls whether the register stores new data or keeps its current value</li> </ul>
#
# </div>

# %%
# always @(posedge clk) begin 
    # if (enable) 
        # data_register <= data_in; 
# end

# %% [markdown]
# <div style="background-color: #f1f7ed; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <ul> <li>when enable = 1, the register stores the input value at the next clock edge</li> </ul>
# <ul><li>when enable = 0, the register keeps its previous value</li> </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #e2efdb; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Register with Reset & Enable:</h3>
#
# <ul> <li>an enable signal controls whether the register stores new data or keeps its current value</li> </ul>
#
# </div>

# %%
# always @(posedge clk) begin
    # if (reset)
        # data_register <= 8'b00000000;
    # else if (enable)
        # data_register <= data_in;
# end

# %% [markdown]
# <div style="background-color: #f1f7ed; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <ul> <li>check reset</li> </ul>
# <ul><li>check enable</li> </ul>
# <ul> <li>otherwise keep previous value</li> </ul>
#
#
# </div>

# %% [markdown]
# <div style="background-color: #e2efdb; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Parallel Register:</h3>
#
# <ul> <li>loads and outputs multiple bits at the same time</li> </ul>
# <br>
#     <b>Example (8-bit parallel register):</b>
# <ul> 8 input bits → 8-bit register → 8 output bits</ul>
# <ul> <li>all eight bits are stored during the same clock edge</li> </ul>
#
# </div>

# %%
# always @(posedge clk) begin 
    # output_data <= input_data; 
# end

# %% [markdown]
# <div style="background-color: #f1f7ed; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <ul> <li>if input_data: 10110110</li> </ul>
# <ul><li>then after next rising edge, output_data: 10110110</li> </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #e2efdb; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Shift Register:</h3>
#
# <ul> <li>moves stored bits left or right by one position during each clock cycle</li> </ul>
#
# <div style="background-color: #f1f7ed; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <b>shift registers are commonly used for:</b>
# <ul> <li>serial communication</li> </ul>
# <ul> <li>UART</li> </ul>
# <ul> <li>SPI</li> </ul>
# <ul> <li>data conversion</li> </ul>
# <ul> <li>delays</li> </ul>
# <ul> <li>pattern generation</li> </ul>
#
# </div>

# %%
# always @(posedge clk) begin 
    # shift_register <= {serial_in, shift_register[7:1]}; 
# end

# %% [markdown]
# <div style="background-color: #f1f7ed; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <b>during every clock edge:</b>
# <ul> <li>each bit moves one position to the right</li> </ul>
# <ul> <li>a new bit enters the register from the left</li> </ul>
# <ul> <li>one bit leaves the register from the right</li> </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #e2efdb; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Storage Register:</h3>
#
# <ul> <li>holds a value so that other parts of the circuit can use it later</li> </ul>
#
# <div style="background-color: #f1f7ed; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <b>storage registers can store:</b>
# <ul> <li>counter values</li> </ul>
# <ul> <li>sensor readings</li> </ul>
# <ul> <li>arithmetic results</li> </ul>
# <ul> <li>state-machine states</li> </ul>
# <ul> <li>communication data</li> </ul>
# <ul> <li>processor instructions</li> </ul>
#
# </div>

# %%
# always @(posedge clk) begin 
    # result_register <= a + b;
# end

# %% [markdown]
# <div style="background-color: #f1f7ed; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <ul> <li>the adder calculates a + b, and the result is stored in the register at the next clock edget</li> </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #e2efdb; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Registers vs Variables:</h3>
#
# <ul> <li>a hardware register is a physical storage circuit, while a software variable is data stored and managed by a processor</li> </ul>
#
# <div style="background-color: #f1f7ed; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <ul> <li>software variable → data used by a processor</li> </ul>
# <ul> <li>HDL register → physical hardware that stores data</li> </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #e2efdb; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <h3 style="font-size: 20px; font-weight: bold;">Registers vs Memory:</h3>
#
# <ul> <li>registers are usually faster but require more hardware for each stored bit</li> </ul>
#
# <div style="background-color: #f1f7ed; padding: 12px; border-radius: 10px; font-size: 16px; font-family: Times;">
# <ul> <li>register → purpose → stores small amounts of data</li> </ul>
# <ul> <li>memory → purpose → stores larger amounts of data</li> </ul>
# <ul> <li>register → speed → very fast</li> </ul>
# <ul> <li>memory → speed → slower</li> </ul>
# <ul> <li>register → hardware → flip-flops</li> </ul>
# <ul> <li>memory → hardware → BRAM, RAM, memory cells</li> </ul>
# <ul> <li>register → common size → few bits or words</li> </ul>
# <ul> <li>memory → common size → many words of data</li> </ul>
# <ul> <li>register → typical function → current values & results</li> </ul>
# <ul> <li>memory → typical function → programs, buffers, large datasets</li> </ul>
#
#
# </div>
